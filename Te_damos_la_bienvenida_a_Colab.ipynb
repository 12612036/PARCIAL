# %% [markdown]
# <a href="https://colab.research.google.com/github/12612036/PARCIAL/blob/main/Te_damos_la_bienvenida_a_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset('tips')

# %%
sns.displot( tips, x= "total_bill", kde= True, rug = True)

# %%
sns.displot( tips, x= "total_bill", kind = "kde")

# %%
sns.displot( tips, x= "total_bill", kind = "ecdf")

# %%
sns.displot( tips, x= "total_bill",y= "tip")

# %%
sns.displot(tips, x="total_bill", hue="day", multiple="stack")

# %%
sns.displot(tips, x="total_bill", kind="kde", hue="day")

# %%
sns.displot(tips, x="total_bill", hue="day", multiple= "dodge" , bins = 5, shrink = 0.8)

# %%
sns.displot(tips, x="total_bill", hue="day", multiple= "dodge" , bins = 5, shrink = 0.8,
height = 5, aspect = 0.8)

# %%
sns.displot(tips, x="total_bill", hue="day", multiple= "dodge" , bins = 5, shrink = 0.8, col = "day",
height = 5, aspect = 0.5)

# %%
sns.displot(tips, x="total_bill", hue="day", multiple= "dodge" , bins = 5, shrink = 0.8, col = "day",row = "time",
height = 5, aspect = 0.5)
